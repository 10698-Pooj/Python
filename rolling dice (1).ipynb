# %%
import random 
import string

# %%
def roll():
    roll_dice=random.randint(1,6)
    return roll_dice
print(roll())
print(roll())
print(roll())
print(roll())
# Out:
# 5
# 4
# 2
# 6

# %%
def main():
    P1=0
    P1score=0
    P2=0
    P2score=0
    rds=1 #number of rounds
    
    while rds!=4:
        print("Round_"+str(rds))
        P1=roll()
        P2=roll()
        print("Player1's roll:"+str(P1))
        print("Player2's roll:"+str(P2))
        
        if P1==P2:
            print("draw")
        elif P1>P2:
            P1score=P1score+1
            print("Player1 wins")
        else:
            P2score=P2score+1
            print("Player2 wins")
        print()
        rds = rds+1
    print()
    if P1score == P2score:
         print("draw")
    elif P1score>P2score:
        print("Player 1 wins")
        print("score of player 1 is:"+str(P1score))
    else:
        print("Player 2 wins")
        print("score of player 2 is:"+str(P2score))

def roll():
    roll_dice=random.randint(1,6)
    return roll_dice
main()
# Out:
# Round_1
# Player1's roll:5
# Player2's roll:6
# Player2 wins
#
# Round_2
# Player1's roll:4
# Player2's roll:4
# draw
#
# Round_3
# Player1's roll:5
# Player2's roll:5
# draw
#
#
# Player 2 wins
# score of player 2 is:1

# %%
ch ="z"
while ch !="c" and ch !="b":
    print("""
************************************************************************************************************************
Choose what you would like to see from the following menu(press c to exit):
************************************************************************************************************************
a: Read the instructions for playing the game of ROLLING THE DICE.
b: Play a game of Rolling the Dice
c: Exit the session
""")
    choice = input("\t Type in your choice (a,b or c): ")
    print
    if ch == "a":
        print("""
************************************************************************************************************************
ROLL THE DICE - GENERAL RULES FOR PLAYING ONE GAME OF ROLL THE DICE 
A playes throws two die .Each dice has six faces.These faces contain 1, 2, 3, 4, 5 and 6 spots respectively. After the 
dice comes to rest,the sum of the spots of the two upward faces is calculated .
- If the sum is 7 or 11 on this throw, the playes wins.
- If the sum is 2, 3, or 12 on this throw ,the player loses.
- if the sum is 4, 5, 6, 8, 9 or 10 on this throw the game continues and the sum becomes the player's "target".
To win, the playes mst continue rolling the dice until the sum is of the dice "hits the target"(i.e...throws his target 
value ).The playes loses by rolling a sum of 7 by hitting the target.
************************************************************************************************************************
""")
    elif ch =="b":
        print("""
*************************************
YOUR STARTING TO ROLL THE DICE GAME
*************************************
GOODLUCK!
""")
        
    elif ch == "c":
        print("""
**********************************
YOU ARE CLOSING DOWN THE GAME....
**********************************
GOODBYE.....
""")
    else:
        print("WARNING : " ,)
        print("WARNING" )
        print("\t Sorry, there was an error in your input to see your choice, ") 
        print("\t\t you should have typed in a, b, one with lower case letter") 
        print("\t\t Please. .type (c) To exit.") 
        print()
   
    print()
    play = True
    totalgame = 0
    totalWon = 0
    totalLost= 0
    count = 0 # counts the number of game input
    answer = "y" # ensures that the while Loop condition is True initiaLly
    answer = input("\WOULD YOU LIKE TO PLAY ROLLING DICE GAME? (y/n): ")
    print(play)
    print(totalgame)
    print(totalWon)
    print(totalLost)
    print(count)
    print(answer)
    print()
    print()
    
    if answer == 'y':
        roll_dice = random.randint (1, 12) #sum of 2 dice roll
        print (roll_dice)
        totalgame = totalgame + roll_dice
        count = count + 1
        if roll_dice == 7 or roll_dice  == 11:
            x = int(input("type in (1) for this")) 
            print("CONGRATULATIONS!, You won the game")
            totalWon = totalWon + x
        elif roll_dice == 2 or roll_dice == 3 or roll_dice == 12:
            y = int(input("type in (1) for this")) 
            print("Sorry you lost the game. Better Luck Next Time!")
            totalLost = totalLost + y
        else:
            print("Continue the game with roll_dice as your target score")
            r = int(input("Do you want to continue [y =1/n=0]:"))
            a = 1
            roll_dice2 = random.randint (1, 12)
            print(roll_dice2)
            while a == "r" :
                if roll_dice2 == 7:
                    y1 = int(input("type in (1) for this")) 
                    print ("Your Loose! Thank you for playing.")
                    totalLost = totalLost +y1
                    break
                elif roll_dice2 == 4 or roll_dice2 == 5 or roll_dice2 == 6 or roll_dice2 == 8 or roll_dice2 == 9 or roll_dice2 == 10:
                    if roll_dice2 == roll_dice:
                        x1=input("type in(1)for this")
                        print("Congrata!,you won the game")
                        totalWon=totalWon+x1
                        break
                    elif roll_dice2!=roll_dice:
                        print("\t the score[",roll_dice2,"]is diferent from target score[",roll_dice,"]")
                        print("continue till DR2 is not equal to ur target score")
                        break
                    else:
                        print("thank you for using the game . session ends")
                        break
                        a+=1
                else:
                    print("thank you for using the game . session ends")
                    break
    else:
        print("thank you for using the game . session ends")
    if totalgame!=0:
        percentageWon=totalWon*100/totalgame
        print()
        print("\t******************************************************")
        print("\n\tThe total number of games player played is:",totalgame)
        print("\n\tThe number of games won is:",totalWon)
        print("\n\tThe number of games lost is:",totalLost)
        print("\n\tThe percentage of games won is:",percentageWon,"%")
        print()
        print("\t******************************************************")
    else:
        print()
        print("\t******************************************************")
        print("\n\tThe total number of games players played is:0")
        print("\n\tThe number of games won is:0")
        print("\n\tThe number of games lost is:0")
        print("\n\tThe percentage of games won is:0")
        print()
        print("\t******************************************************")
